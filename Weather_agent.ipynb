# %%
from langchain_community.llms import Ollama
llm=Ollama(model="llama3:8b")
response=llm.invoke("this is langchain te|st if you can listen hey hello langchain")
print(response)
# Out:
# C:\Users\palar\AppData\Local\Temp\ipykernel_10708\1759174910.py:2: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm=Ollama(model="llama3:8b")
# It looks like LangChain is testing my language understanding skills!
#
# Hello! I can hear you, LangChain! It seems like we're having a conversation. How's the test going so far? Are you evaluating my ability to understand natural language and respond accordingly?

# %%
from langchain_core.prompts import PromptTemplate,ChatPromptTemplate

# %%
from langchain_core.output_parsers import JsonOutputParser

# %%
prompt = PromptTemplate.from_template(
    "you need to return the latitude and the longitude of a {input} in json format with the key of latitude and longitude"
    
)

# %%
response=chain.invoke("vadodara")
print(response)
# Out:
# {'latitude': 22.3, 'longitude': 73.2}

# %%
import requests

# %%
data['current_weather']['temperature']
# Out:
# 29.7

# %%
def get_weather(data):
    latitude=data["latitude"]
    longitude=data["longitude"]
    url = f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&current_weather=true"
    response=requests.get(url)
    temp=response.json()
    return temp['current_weather']['temperature']

# %%
from langchain_core.runnables import RunnableLambda

# %%
cw=RunnableLambda(get_weather)
chain=prompt|llm|JsonOutputParser()|cw

# %%
response=chain.invoke("vadodara")
print(response)
# Out:
# 31.1

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/palar/Langchain/.git/

# %%
# !git branch -M main

# %%
# !git commit -
